# %% [markdown]
# <a href="https://colab.research.google.com/github/motoca/hackaton/blob/main/hachaton_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Configurações Inicias

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd ./drive/MyDrive/TI/Cursos/FIAP/projeto-final/
# %pwd
# Out:
# /content/drive/MyDrive/TI/Cursos/FIAP/projeto-final
# '/content/drive/MyDrive/TI/Cursos/FIAP/projeto-final'

# %% [markdown]
# Clonando o repositório do projeto com o modelo para detecção de obetos cortantes em imagens e vídeos

# %%
# !git clone https://github.com/motoca/hackaton.git
# !git pull
# Out:
# fatal: destination path 'hackaton' already exists and is not an empty directory.

# %%
# %pwd
# %cd hackaton/white_weapon_detection
# Out:
# '/content/drive/MyDrive/TI/Cursos/FIAP/projeto-final/hackaton/white_weapon_detection/yolov5'

# %% [markdown]
# Instalando as dependências

# %%
# %pip install -qr requirements.txt
# Out:
# WARNING: Skipping utils as it is not installed.

# %%
import torch
import warnings
import utils

warnings.filterwarnings('ignore')
# display = utils.notebook_init()  # checks

# %% [markdown]
# Treinando o modelo com as imagens do dataset selecionado

# %%
# !python train.py
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
#       94/99      16.2G    0.02222   0.005814  8.264e-05         18        640:  97% 478/493 [01:42<00:03,  4.64it/s]/content/drive/MyDrive/TI/Cursos/FIAP/projeto-final/hackaton/white_weapon_detection/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       94/99      16.2G    0.02223   0.005819  8.267e-05         28        640:  97% 479/493 [01:42<00:02,  4.68it/s]/content/drive/MyDrive/TI/Cursos/FIAP/projeto-final/hackaton/white_weapon_detection/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...

# %% [markdown]
# Executando a detecção de objetos

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.50 --source data/images
#!python detect.py --weights yolov5x.pt --img 640 --conf 0.50 --source data/videos/video2.mp4
#!python detect.py --weights yolov5x.pt --img 640 --conf 0.50 --source 0

# %% [markdown]
# Visualizando objetos detectados

# %%
display.Image(filename='runs/detect/exp6/img-teste.jpg', width=640)
#display.Video(filename='runs/detect/exp4/video2.mp4')
